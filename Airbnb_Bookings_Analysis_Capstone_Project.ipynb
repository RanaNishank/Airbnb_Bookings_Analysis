# %% [markdown]
# <a href="https://colab.research.google.com/github/RanaNishank/Airbnb_Bookings_Analysis/blob/main/Airbnb_Bookings_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# ## <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# ## <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %% [markdown]
# <br>

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**
#
# > **EDA allows us to:**
#
# *   **Better understand the data:** Getting domain knowledge by reading some articles about the topic you are working on. You don't need to go to deep.
# *   **Build intuition about the data:** Check if the data agree with the our domain knowledge.
# *   **Generate hypotheses:** Understand how the data was generated, Find insights, and try to predict the output.
# *   **Exploring anonymized data:** Explore individual features, check if the values match with our domain knowledge. Explore features relations.
# <br>
# <br>
#
#   ***Now, it's time to have fun!***

# %% [markdown]
# #**Importing Modules and Loading Data**

# %%
# Importing the required packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Storing the path of the dataset in 'path' variable
path = '/content/drive/MyDrive/EDA Capstone Project/Airbnb NYC 2019.csv'

# %%
# Reading the Airbnb.csv
df = pd.read_csv(path)

# %% [markdown]
# # **Understand More About The Data**

# %%
# Viewing the data of top 5 rows to look the glimps of the data
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
# View the data of bottom 5 rows to look the glimps of the data
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood        room_type  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant     Private room
# 48891        Marisol            Brooklyn            Bushwick     Private room
# 48892  Ilgar & Aysel           Manhattan              Harlem  Entire home/apt
# 48893            Taz           Manhattan      Hell's Kitchen      Shared room
# 48894     Christophe           Manhattan      Hell's Kitchen     Private room
#
# ...

# %%
# Getting the shape of dataset with rows and columns
print(df.shape)
# Out:
# (48895, 14)

# %% [markdown]
# **Observations:**
# *   Total 16 columns are present in the dataset.
# *   Total 48895 rows are present in the dataset.
#
# ---
# In our Dataset and we have informations such as ID, host id, hosts name along with their listing and price, neighbourhood, neighbourhood group, minimum nights, geographical coordinates, number of reviews, reviews per month and availability 365
#
# ---

# %%
# Using info() method we can easily get the idea of what kind of data type and null values inside the DataFrame we have
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   room_type                       48895 non-null  object
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  last_review                     38843 non-null  object
#  11  reviews_per_month               38843 non-null  float64
# ...

# %%
# Calculating the null or missing values
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# **Observations:**
#
# *   There are a total of four columns with null values. Which are 'name' , 'host_name' , 'last_review' and 'review_per_month'.
# *   The name column has 16 null values.
# *   host_name has 21 null values.
# *   last_review and reviews_per_month are having more null values.
#
# We will look at the columns and decide what we can do with them.

# %%
# Getting the columns name inside our dataframe
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# Check statisical summary of dataset and now, we can see the numeric value and its aggregations like mean, median and mode using Describe method
df.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  4.889500e+04  4.889500e+04  48895.000000    48895.000000
# mean   1.901714e+07  6.762001e+07    152.720687        7.029962
# std    1.098311e+07  7.861097e+07    240.154170       20.510550
# min    2.539000e+03  2.438000e+03      0.000000        1.000000
# 25%    9.471945e+06  7.822033e+06     69.000000        1.000000
# 50%    1.967728e+07  3.079382e+07    106.000000        3.000000
# 75%    2.915218e+07  1.074344e+08    175.000000        5.000000
# max    3.648724e+07  2.743213e+08  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       38843.000000                    48895.000000
# mean           23.274466           1.373221                        7.143982
# std            44.550582           1.680442                       32.952519
# min             0.000000           0.010000                        1.000000
# ...

# %% [markdown]
# **Observations**
# *   Min of Price variable is 0, max is 10000.
# *   Mean price is 152.
# *   On an average people stay 7 days in a room.

# %%
# Checking the mean, mode and median for specific columns
df[['price','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']].describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48895.000000    48895.000000       48895.000000       38843.000000
# mean     152.720687        7.029962          23.274466           1.373221
# std      240.154170       20.510550          44.550582           1.680442
# min        0.000000        1.000000           0.000000           0.010000
# 25%       69.000000        1.000000           1.000000           0.190000
# 50%      106.000000        3.000000           5.000000           0.720000
# 75%      175.000000        5.000000          24.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# ...

# %%
# Using head() with Transpose function to view all columns and filter out only those columns which is necessary for our analysis.
df.head().T
# Out:
#                                                                  0  \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# reviews_per_month                                             0.21
# calculated_host_listings_count                                   6
# ...

# %%
# Selecting those columns which are important for our analysis
df = df[['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
       'neighbourhood','room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365']]

# %%
# Now making a copy of this dataframe for safety perpose or furthur use.
df = df.copy()

# %% [markdown]
# Now we successfully filtered out our dataframe and now we know what type of information our dataset holds and get an idea of what kind of information we are looking for inside our dataframe.

# %% [markdown]
# # **Data Visualization**
#
# > Visualize your data and search for pattern that can help you solve your problem.

# %%
# Visualizing the distribution for every "feature"
df.hist(edgecolor="black", linewidth=1.2, figsize=(30, 30));

# %% [markdown]
# # **Correlation Check**
#
# > Let's check the correlation matrix to understand how are the features interrelated with each other.<br>
# > Also to get an idea which are the most important features in this data.

# %%
# let's check the correlation using heatmap
plt.figure(figsize=(20,8))
plt.title('Correlation', fontsize = 30)
sns.heatmap(df.corr(),annot = True)
plt.show()

# %% [markdown]
# * Clearly from the heatmap we can see the correlation between different features that can affect an airbnb listing.
#
# * Guess what? There's correlation among host_id to reveiws_per_month & availability_365. Also there's a noticeable correlation between min_nights to calculated_host_listings_count  & availability_365. Price also shows some correlation with availability_365 & calculated_host_listings_count .
#
# * number_of_reviews and reviews_per_month gives almost the same information. so we can carry out analysis with any of the two variables. Also, number_of_reviews is correlated to availability_365!

# %% [markdown]
# <br>

# %% [markdown]
# # **What can we learn about different hosts and areas?**
#
# > *Perform groupby function on host_name and areas and aggregation function on calculated_host_listings_count. we get the result, which tells us about the host_name and total number of listed properties at different neighbourhood_group.*

# %%
# Performing groupby on host_name and calculated_hosts_listings and Sorting values by calculated_host_listings_count
hosts_listings = df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
highest_calculated_host_listings_count = hosts_listings.sort_values(by='calculated_host_listings_count', ascending=False).head(10)
highest_calculated_host_listings_count
# Out:
#                host_name neighbourhood_group  calculated_host_listings_count
# 13217       Sonder (NYC)           Manhattan                             327
# 1834          Blueground           Manhattan                             232
# 1833          Blueground            Brooklyn                             232
# 7275                Kara           Manhattan                             121
# 7480              Kazuya              Queens                             103
# 7479              Kazuya           Manhattan                             103
# 7478              Kazuya            Brooklyn                             103
# 13216             Sonder           Manhattan                              96
# 6540      Jeremy & Laura           Manhattan                              96
# 2901   Corporate Housing           Manhattan                              91

# %%
# Using matplotlib libraries for ploting the bar chat of hosts with highest calculated host listings count
host_name = highest_calculated_host_listings_count['host_name']
calculated_host_listings_count = highest_calculated_host_listings_count['calculated_host_listings_count']
plt.bar(host_name,calculated_host_listings_count, color='red')

plt.rcParams['figure.figsize'] = (25,10)
plt.title('Hosts with Highest Host Listings', {'fontsize':15})
plt.xlabel('Host Names',{'fontsize':15})
plt.ylabel('Host listings count',{'fontsize':15})
plt.show()

# %% [markdown]
# In this following output we can see that the host_name *Sonder(NYC)* have most listing of 327 properties in *Manhattan Area*

# %%
# Hosts and neighbourhood groups
hosts_per_neighbourhood_group = df.groupby(['neighbourhood_group'])['room_type'].count().reset_index().rename(columns={'room_type':'number_of_airbnb'}).sort_values(by='number_of_airbnb',ascending=False).head(10)
hosts_per_neighbourhood_group
# Out:
#   neighbourhood_group  number_of_airbnb
# 2           Manhattan             21661
# 1            Brooklyn             20104
# 3              Queens              5666
# 0               Bronx              1091
# 4       Staten Island               373

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize and understanding.
neighbourhood = hosts_per_neighbourhood_group['neighbourhood_group']
num_of_bnb = hosts_per_neighbourhood_group['number_of_airbnb']

fig = plt.figure(figsize = (15,5))
# Creating the bar plot
plt.bar(neighbourhood, num_of_bnb,color = ['darkgreen','green','limegreen','springgreen','lightgreen'])

plt.xlabel("Neighbourhood",fontsize=20)
plt.ylabel("number of Airbnb",fontsize=20)
plt.title('Number of hosts in each neighbourhood group',fontsize=20)
plt.xticks(fontsize='15')
plt.show()

# %% [markdown]
# **Observations:**
#
# *   Manhattan has 21661 numbers of Airbnb available.
# *   Brooklyn has 20104 numbers of Airbnb available.
# *   Queens has 5666 numbers of Airbnb available.
# *   The Bronx has 1091 numbers of Airbnb available.
# *   Staten Island has 373 numbers of Airbnb available.
#
#
# ---
#
#
# As we can see in upper bar charts. Which tells that the darker color means more the number of airbnb available in a particular neighbourhood.
#
#
#
#
# ---

# %%
# Getting the number of Airbnb available in each neighbourhood group
num_of_room_in_neighbourhood = pd.DataFrame(df.groupby('neighbourhood_group')['room_type'].value_counts())
num_of_room_in_neighbourhood
# Out:
#                                      room_type
# neighbourhood_group room_type
# Bronx               Private room           652
#                     Entire home/apt        379
#                     Shared room             60
# Brooklyn            Private room         10132
#                     Entire home/apt       9559
#                     Shared room            413
# Manhattan           Entire home/apt      13199
#                     Private room          7982
#                     Shared room            480
# Queens              Private room          3372
#                     Entire home/apt       2096
#                     Shared room            198
# Staten Island       Private room           188
#                     Entire home/apt        176
#                     Shared room              9

# %% [markdown]
# # **What can we learn from predictions? (ex: Locations, Prices, Reviews, etc)**
#
# > *Now Grouping neighbourhood with reviews to see which neighbourhood group has more visitors.*

# %%
# Reviews and neighbourhood groups and taking max of number of reviews and price.
reviews_per_neighbourhood_group  = df.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index().sort_values(by='number_of_reviews',ascending=False)
reviews_per_neighbourhood_group
# Out:
#   neighbourhood_group  number_of_reviews
# 3              Queens                629
# 2           Manhattan                607
# 1            Brooklyn                488
# 4       Staten Island                333
# 0               Bronx                321

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize and understanding.
neighbourhoods = reviews_per_neighbourhood_group['neighbourhood_group']
reviews = reviews_per_neighbourhood_group['number_of_reviews']

fig = plt.figure(figsize = (10, 5))

# Creating the bar plot
color = ['darkgreen','green','limegreen','springgreen','lightgreen']
plt.bar(neighbourhoods, reviews,color=color)

plt.xlabel("Neighbourhood",fontsize=20)
plt.ylabel("Visitors",fontsize=20)
plt.title("Number of reviews in each neighbourhood group",fontsize=20)
plt.xticks(fontsize='12')
plt.show()

# %% [markdown]
# **Observations**
#
# *   Queens has the most number of visitors which is 629.
# *   Manhattan has the most number of visitors which is 607.
# *   Brooklyn has the most number of visitors which is 488.
# *   Staten Island has the most number of visitors which is 333.
# *   The Bronx has the most number of visitors which is 321.
# <br>
# <br>
# Most of the people likes Queens and Manhattan and From the above 2 graphs (i.e. Number of hosts in each neighbourhood group & Number of reviews in each neighbourhood group), it can be seen that even with moderate number of hosts in Queens, it generated the highest revenue out of all the nieghbourhood group.

# %% [markdown]
# ---
# ##**Now checking the number of visitors on monthly basis.**
#
# ---

# %%
# Firstly droping the null values then using groupby on neighbourhood_group and taking max of reviews per month and price.
neighbourhood_reviews_per_month = df[~df['reviews_per_month'].isna()].groupby(['neighbourhood_group'])['reviews_per_month'].max().reset_index()
neighbourhood_reviews_per_month
# Out:
#   neighbourhood_group  reviews_per_month
# 0               Bronx              10.34
# 1            Brooklyn              14.00
# 2           Manhattan              58.50
# 3              Queens              20.94
# 4       Staten Island              10.12

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize and understanding.
neighbourhoods_for_month = neighbourhood_reviews_per_month['neighbourhood_group']
reviews_per_month = neighbourhood_reviews_per_month['reviews_per_month']

fig = plt.figure(figsize = (10, 5))

# Creating the bar plot
color = ['cornflowerblue','steelblue','midnightblue','mediumslateblue','lightsteelblue']
plt.bar(neighbourhoods_for_month, reviews_per_month,color=color)

plt.xlabel("Neighbourhood",fontsize=18)
plt.ylabel("Visitors Per Month",fontsize=18)
plt.title("Neighbourhood vs Visitors Per Month",fontsize=18)
plt.xticks(fontsize='12')
plt.show()

# %%
# Getting the last review along with neighbourhood group
df.groupby(['neighbourhood_group','last_review'])['reviews_per_month'].max().reset_index().sort_values(by='reviews_per_month',ascending=False).head().set_index('neighbourhood_group')
# Out:
#                     last_review  reviews_per_month
# neighbourhood_group
# Manhattan            2019-07-07              58.50
# Queens               2019-07-08              20.94
# Queens               2019-07-06              19.75
# Queens               2019-07-05              15.78
# Queens               2019-06-26              15.23

# %% [markdown]
# **Observations:**
#
# *   The Queens neighbourhood got more visitors. But when we did our aggregation function on visitors per month. We find that Manhattan has more number of visitors per month as compared to Queens and other neighbourhoods.
# *   The reasons behind why we get Manhattan on top in July month.
# The Fourth of July is the independence day of America. On this day there is a federal holiday across the entire America.

# %% [markdown]
# ---
#
# ##**Now checking which neighbourhood has maximum price per night?**
#
#
# ---

# %%
# Getting the maximum labeled price airbnb available in different neighbourhood
neighbourhood_prices = df[df['minimum_nights']==1].groupby(['neighbourhood_group'])['price'].max().reset_index().sort_values(by=['price'])
neighbourhood_prices.head(10)
# Out:
#   neighbourhood_group  price
# 0               Bronx   1000
# 3              Queens   2000
# 4       Staten Island   5000
# 2           Manhattan   7703
# 1            Brooklyn   8000

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize or better understanding the neighbourhood_group vs Price.
location = neighbourhood_prices['neighbourhood_group']
price = neighbourhood_prices['price']

fig = plt.figure(figsize = (10, 5))
color = ['lightblue','cornflowerblue','royalblue','blue','darkblue']

# Creating the bar plot
plt.bar(location,price,color=color)
plt.xlabel("Neighbourhood",fontsize=20)
plt.ylabel("Price Per Night",fontsize=20)
plt.title("Neighbourhood vs Maximun Price",fontsize=20)
plt.xticks(fontsize='12')
plt.show()

# %% [markdown]
# **Observation:**
#
# *   From this above bar plot we can see that Brooklyn and Manhattan neighbourhood groups have maximum price tagged Airbnb.
# *   Staten Island has low prices as compared to Brooklyn and Manhattan. But higher than the Bronx and Queens in Neighbourhood.
# *   The Bronx has low prices as compared to others.

# %% [markdown]
# ---
# ## **Now checking which neighbourhood has minimum price per night?**
#
# ---

# %%
# Droping null values from price column in airbnb dataframe
df[~df['price'].isna()].groupby('neighbourhood_group')[['minimum_nights','price']].min()
# Out:
#                      minimum_nights  price
# neighbourhood_group
# Bronx                             1      0
# Brooklyn                          1      0
# Manhattan                         1      0
# Queens                            1     10
# Staten Island                     1     13

# %% [markdown]
# There might be a mistake by the person who works to record the entries.
# <br>
# Getting those rows where the price is more than zero. So Simply apply Conditions on our dataframe where the price should be more than zero.

# %%
# Using conditon on airbnb dataset.
min_price_airbnb = df[df['price']>0].groupby('neighbourhood_group')[['minimum_nights','price']].min().reset_index()
min_price_airbnb
# Out:
#   neighbourhood_group  minimum_nights  price
# 0               Bronx               1     10
# 1            Brooklyn               1     10
# 2           Manhattan               1     10
# 3              Queens               1     10
# 4       Staten Island               1     13

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize and understanding.
location = min_price_airbnb['neighbourhood_group']
price = min_price_airbnb['price']

fig = plt.figure(figsize = (10, 5))
color = ['lightblue','cornflowerblue','royalblue','blue','darkblue']

# Creating the bar plot
plt.bar(location,price,color=color)
plt.xlabel("Neighbourhood",fontsize=30)
plt.ylabel("Price",fontsize=30)
plt.title("Price Per Night vs Neighbourhood",fontsize=25)
plt.xticks(fontsize='12')
plt.show()

# %%
# Price and reviews
price_reviews = df.groupby(['price'])['number_of_reviews'].max().reset_index()
print(price_reviews)
plt.scatter(price_reviews['price'],price_reviews['number_of_reviews'])

plt.rcParams['figure.figsize'] = (8,6)
plt.title('Price vs Number of reviews')
plt.xlabel('Price')
plt.ylabel('Number of reviews')
plt.show()
# Out:
#      price  number_of_reviews
# 0        0                 95
# 1       10                 93
# 2       11                113
# 3       12                  8
# 4       13                  9
# ..     ...                ...
# 669   7703                  0
# 670   8000                  1
# 671   8500                  2
# 672   9999                  6
# 673  10000                  5
#
# [674 rows x 2 columns]

# %% [markdown]
# **Observations:**
#
# *   Most of the guests prefer cheaper price.

# %% [markdown]
# <br>

# %% [markdown]
# # **Which hosts are the busiest and why?**

# %%
# Using groupby on host_id, host_name, room_type and neighbourhood_group with respect to maximun number of reviews
busiest_host = df.groupby(['host_name','room_type','neighbourhood_group'])['number_of_reviews'].max().reset_index().rename(columns={'number_of_reviews':'number_of_booking'})
busiest_host
# Out:
#                       host_name        room_type neighbourhood_group  \
# 0                          'Cil     Private room              Queens
# 1               (Ari) HENRY LEE  Entire home/apt           Manhattan
# 2      (Email hidden by Airbnb)  Entire home/apt            Brooklyn
# 3      (Email hidden by Airbnb)  Entire home/apt           Manhattan
# 4      (Email hidden by Airbnb)     Private room           Manhattan
# ...                         ...              ...                 ...
# 19144                        빈나     Private room           Manhattan
# 19145                        소정     Private room            Brooklyn
# 19146                        소정     Private room           Manhattan
# 19147                         진  Entire home/apt           Manhattan
# 19148                        현선     Private room           Manhattan
#
#        number_of_booking
# 0                    240
# 1                      3
# 2                      5
# 3                      1
# ...

# %%
# Sort by number of bookings
top_10_busiest_host = busiest_host.sort_values(by='number_of_booking',ascending=False).head(10)
top_10_busiest_host
# Out:
#       host_name        room_type neighbourhood_group  number_of_booking
# 4598       Dona     Private room              Queens                629
# 8445         Jj     Private room           Manhattan                607
# 12044      Maya     Private room              Queens                543
# 2869      Carol     Private room           Manhattan                540
# 3988   Danielle     Private room              Queens                510
# 1637        Asa  Entire home/apt            Brooklyn                488
# 18272     Wanda     Private room            Brooklyn                480
# 10578     Linda     Private room              Queens                474
# 3935       Dani  Entire home/apt            Brooklyn                467
# 1179     Angela     Private room              Queens                466

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize and understanding to know how many bookings got the top hosts.
top_10_hosts_name = top_10_busiest_host['host_name']
num_booking = top_10_busiest_host['number_of_booking']

fig = plt.figure(figsize = (10, 5))

# Creating the bar plot
plt.bar(top_10_hosts_name,num_booking)
plt.xlabel("Host",fontsize=20)
plt.ylabel("Bookings",fontsize=20)
plt.title("Host vs Number of Bookings",fontsize=20)
plt.xticks(fontsize='12')
plt.show()

# %% [markdown]
# **Observations:**
#
# *   Dona, Jj, Maya, Carol and Danielle are the busiest host.

# %% [markdown]
# ---
# ## **Want to Know why these host are busiest?**
#
# ---

# %%
# Performing the value_count() function on room_type column
pd.DataFrame(top_10_busiest_host['room_type'].value_counts())
# Out:
#                  room_type
# Private room             8
# Entire home/apt          2

# %% [markdown]
# As we can see the above code output which shows us that, majorly hosts have "Private Room" as room_type . Which people prefer more.

# %%
# Getting the top 5 hosts location and minimum offering price for different room type
top_5_hosts_df = df[(df.loc[:,'host_name']=='Dona') | (df.loc[:,'host_name']=='Jj') | (df.loc[:,'host_name']=='Maya') | (df.loc[:,'host_name']=='Carol') | (df.loc[:,'host_name']=='Danielle')]
top_5_hosts_min_price_df =top_5_hosts_df.groupby(['host_name','price','room_type','neighbourhood_group'])['minimum_nights'].min().reset_index().sort_values(by=['minimum_nights','price']).set_index('host_name').reset_index().loc[[0,1,2,7,11]]
top_5_hosts_min_price_df
# Out:
#    host_name  price     room_type neighbourhood_group  minimum_nights
# 0       Maya     32  Private room              Queens               1
# 1      Carol     35  Private room            Brooklyn               1
# 2   Danielle     38   Shared room              Queens               1
# 7       Dona     47  Private room              Queens               1
# 11        Jj     49  Private room           Manhattan               1

# %% [markdown]
# **Observations:**
#
# *   Maya offers a private room in Queens neighbourhood at price 32 per night.
# *   Carol offers a private room in a Brooklyn neighbourhood at price 35 per night.
# *   Danielle offers a private room in Queens neighbourhood at price 38 per night.
# *   Dona offers a private room in Queens neighbourhood at price 47 per night.
# *   Jj offers a private room in Manhattan neighbourhood at price 49 per night.

# %% [markdown]
# <br>

# %% [markdown]
# # **Is there any noticeable difference of traffic among different areas and what could be the reason for it?**
#
# > In order to know the traffic areas we have to mainly look into three columns.<br> Which are as follows:-
# *   Neighbourhood group
# *   Room type
# *   Minimum nights

# %%
# Getting the most traffic neighbourhood
trafic_areas = df.groupby('neighbourhood_group')['minimum_nights'].count().reset_index().sort_values(by='minimum_nights',ascending=False)
trafic_areas
# Out:
#   neighbourhood_group  minimum_nights
# 2           Manhattan           21661
# 1            Brooklyn           20104
# 3              Queens            5666
# 0               Bronx            1091
# 4       Staten Island             373

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize and understanding.
neighbourhood_type = trafic_areas['neighbourhood_group']
min_nights = trafic_areas['minimum_nights']

fig = plt.figure(figsize = (10, 5))

# Creating the bar plot
color = ['midnightblue','steelblue','cornflowerblue','mediumslateblue','lightsteelblue']
plt.bar(neighbourhood_type, min_nights,color=color)

plt.xlabel("Neighbourhood Group",fontsize=20)
plt.ylabel("Minimum number of nights stayed",fontsize=20)
plt.title("Traffic Areas in Different Neighbourhood",fontsize=20)
plt.xticks(fontsize='15')
plt.show()

# %% [markdown]
# ---
#
# ##**Now checking what kind of room type people prefer in traffic area like manhattan?**
#
# ---

# %%
# Groupby on neighbourhood_group and room_type with aggregation on ninimun_nights
traffic_among_diff_areas = df.groupby(['neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
traffic_among_diff_areas = traffic_among_diff_areas.sort_values(by='minimum_nights', ascending=False)
traffic_among_diff_areas
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt           13199
# 4             Brooklyn     Private room           10132
# 3             Brooklyn  Entire home/apt            9559
# 7            Manhattan     Private room            7982
# 10              Queens     Private room            3372
# 9               Queens  Entire home/apt            2096
# 1                Bronx     Private room             652
# 8            Manhattan      Shared room             480
# 5             Brooklyn      Shared room             413
# 0                Bronx  Entire home/apt             379
# 11              Queens      Shared room             198
# 13       Staten Island     Private room             188
# 12       Staten Island  Entire home/apt             176
# 2                Bronx      Shared room              60
# 14       Staten Island      Shared room               9

# %%
# Getting only room_type and minimun_nights data
room_type_vs_night = traffic_among_diff_areas[traffic_among_diff_areas['neighbourhood_group']=='Manhattan'].groupby('room_type')['minimum_nights'].sum().reset_index()
room_type_vs_night
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt           13199
# 1     Private room            7982
# 2      Shared room             480

# %%
# Using matplotlib libraries for ploting the bar chart for easy visualize and understanding.
room_type = room_type_vs_night['room_type']
stayed = room_type_vs_night['minimum_nights']

fig = plt.figure(figsize = (10, 5))

# Creating the bar plot
color = ['blue','royalblue','cornflowerblue']
plt.bar(room_type, stayed,color=color)


plt.xlabel("Room Type",fontsize=20)
plt.ylabel("Minimum number of nights stayed",fontsize=20)
plt.title("Traffic Areas",fontsize=20)
plt.xticks(fontsize='15')
plt.show()

# %%
room_type_vs_night_in_manhattan = traffic_among_diff_areas[traffic_among_diff_areas['neighbourhood_group']=='Manhattan'].groupby('room_type')['minimum_nights'].sum().reset_index()
room_type_vs_night_in_manhattan
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt           13199
# 1     Private room            7982
# 2      Shared room             480

# %%
room_type_vs_night_in_brooklyn = traffic_among_diff_areas[traffic_among_diff_areas['neighbourhood_group']=='Brooklyn'].groupby('room_type')['minimum_nights'].sum().reset_index()
room_type_vs_night_in_brooklyn
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt            9559
# 1     Private room           10132
# 2      Shared room             413

# %%
room_type_vs_night_in_queens = traffic_among_diff_areas[traffic_among_diff_areas['neighbourhood_group']=='Queens'].groupby('room_type')['minimum_nights'].sum().reset_index()
room_type_vs_night_in_queens
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt            2096
# 1     Private room            3372
# 2      Shared room             198

# %%
room_type_vs_night_in_bronx = traffic_among_diff_areas[traffic_among_diff_areas['neighbourhood_group']=='Bronx'].groupby('room_type')['minimum_nights'].sum().reset_index()
room_type_vs_night_in_bronx
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt             379
# 1     Private room             652
# 2      Shared room              60

# %%
room_type_vs_night_in_statenisland = traffic_among_diff_areas[traffic_among_diff_areas['neighbourhood_group']=='Staten Island'].groupby('room_type')['minimum_nights'].sum().reset_index()
room_type_vs_night_in_statenisland
# Out:
#          room_type  minimum_nights
# 0  Entire home/apt             176
# 1     Private room             188
# 2      Shared room               9

# %% [markdown]
# **Observations:**
#
# *   'Entire home/apt' type has more demand in traffic areas as compared to 'private room' and 'shared room' and 'Entire home/apt' usually booked by family and who have traveled for short business trips along with family.
# *   'Private room' is usually booked by bachelor's, Couples or travelers who don't want to share privacy with others.
# *   'Shared room' type is mostly booked by students who don't earn much and don't want to spend much money to stay.

# %% [markdown]
# <br>

# %% [markdown]
# ---
# # **Conclusion**
# ---
# *After performing exploratory data analysis on the data set, this is what we have incurred from data:*
# <br>
# <br>
# * The Manhattan neighborhood has the most listed Airbnb as compared to others.
# Queens and Manhattan has the most number of visitors which means people visited more here.
# * In the month of July people visited more in manhattan.
# Brooklyn and Manhattan have a  maximum price which costs more than 5000 because of the metropolitan city.
# * The Bronx neighborhood has their maximum price Airbnb which costs 1000 per night.
# * The top 5 hosts have listed their Airbnb which has room type as private.
# * The major traffic areas are where rooms type as entire home/apartment and private room.
# * Peoples don't like to stay in Airbnb which has room type as shared room.
# * The demand of Airbnb is too high in Manhattan and Queens neighborhoods.
# * In Staten Island the demand of Airbnb is too low as compared to others neighborhoods.
# * In Staten Island the lowest price tagged Airbnb 13 is a little bit higher than other neighborhoods and the maximum price for single night is 5000.
# * In the Staten island neighborhood the pricing of the Airbnb is quite high. Therefor people doesn’t book Airbnb there.
# * It would be better to record the reviews on the scale of 0 to 5. It will help to identify the hosts whose services are better.
